# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Mehrkian_Paper/
# !ls -a
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Mehrkian_Paper
# df_final1.csv		  evaluate.py	      .ipynb_checkpoints  Paper.ipynb	 SentAnalyzer.py
# df_final2.csv		  fine-tuned-model    models.py		  pred1.xlsx	 TEPIX.xlsx
# ecodata.csv		  IndexData1.xlsx     output		  prediction.py
# Eng_labeled_comments.csv  input_tr_200k.xlsx  output_img	  __pycache__

# %%
import transformers
import tensorflow as tf
import keras
print(transformers.__version__)
print(tf.__version__)
print(keras.__version__)
# Out:
# 4.44.2
# 2.17.0
# 3.4.1

# %%
# !pip install transformers
# !pip install persiantools
# !pip install scipy
# !pip install scikit-learn
# !pip install tensorflow==2.15

# %%
import transformers
import tensorflow as tf
import keras
print(transformers.__version__)
print(tf.__version__)
print(keras.__version__)
# Out:
# 4.44.2
# 2.15.0
# 2.15.0

# %%
#!python SentAnalyzer.py
# Out:
# 2024-10-23 15:13:11.248082: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-23 15:13:11.248144: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-23 15:13:11.249907: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-23 15:13:13.892760: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tensorflow version  2.15.0
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ...

# %%
#!python evaluate.py
# Out:
# 2024-10-23 16:06:44.772536: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-23 16:06:44.772593: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-23 16:06:44.782750: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-23 16:06:47.110200: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ...

# %%
# %cd /content/drive/MyDrive/Mehrkian_Paper/
# !ls -a
# Out:
# /content/drive/MyDrive/Mehrkian_Paper
# df_final1.csv		  evaluate.py	      .ipynb_checkpoints  Paper.ipynb	 SentAnalyzer.py
# df_final2.csv		  fine-tuned-model    models.py		  pred1.xlsx	 TEPIX.xlsx
# ecodata.csv		  IndexData1.xlsx     output		  prediction.py
# Eng_labeled_comments.csv  input_tr_200k.xlsx  output_img	  __pycache__

# %%
# !python prediction.py -m 'LSTM' -t 'nocomment'
# Out:
# 2024-10-27 16:10:55.878515: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-27 16:10:55.878563: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-27 16:10:55.879716: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-27 16:10:57.432490: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'LSTM' -t 'comment'
# Out:
# 2024-10-28 10:50:13.658807: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-28 10:50:13.658900: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-28 10:50:13.661526: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-28 10:50:15.802123: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'Transformers' -t 'nocomment'
# Out:
# 2024-11-11 12:28:56.395136: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-11 12:28:56.395186: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-11 12:28:56.396995: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-11 12:28:57.426123: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'Transformers' -t 'comment'
# Out:
# 2024-10-26 16:52:14.148690: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-26 16:52:14.148734: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-26 16:52:14.150018: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-26 16:52:15.233155: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'GRU' -t 'nocomment'
# Out:
# 2024-11-11 12:53:39.833157: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-11 12:53:39.833212: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-11 12:53:39.834533: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-11 12:53:40.918418: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'GRU' -t 'comment'
# Out:
# 2024-11-11 12:54:53.099692: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-11 12:54:53.099743: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-11 12:54:53.101067: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-11 12:54:54.167738: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'FFNN' -t 'nocomment'
# Out:
# 2024-10-26 16:54:09.816068: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-26 16:54:09.816112: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-26 16:54:09.817482: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-26 16:54:10.919009: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'FFNN' -t 'comment'
# Out:
# 2024-10-26 16:55:03.059652: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-26 16:55:03.059704: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-26 16:55:03.060887: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-26 16:55:04.126900: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'CNN_LSTM' -t 'nocomment'
# Out:
# 2024-10-26 16:59:04.217734: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-26 16:59:04.217785: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-26 16:59:04.219143: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-26 16:59:05.265345: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'CNN_LSTM' -t 'comment'
# Out:
# 2024-10-26 17:15:14.134414: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-26 17:15:14.134471: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-26 17:15:14.135868: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-26 17:15:15.209940: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'Bi_LSTM' -t 'nocomment'
# Out:
# 2024-10-27 14:22:30.682305: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-27 14:22:30.682374: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-27 14:22:30.684128: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-27 14:22:32.216244: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...

# %%
# !python prediction.py -m 'Bi_LSTM' -t 'comment'
# Out:
# 2024-10-27 14:27:55.560527: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-27 14:27:55.560600: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-27 14:27:55.563372: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-27 14:27:57.863479: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Trading Days based on IndexData.xlsx  : 298
# TEPIX.xlsx , the whole number of comments about index (shapes) (328528, 2)
#
#
# The number of comments entries (>7 & <50),
# ...
